# %%
import os
from lightrag import LightRAG, QueryParam
from lightrag.llm import openai_complete_if_cache
from lightrag.llm import ollama_embedding
from lightrag.utils import EmbeddingFunc
from dotenv import load_dotenv
import nest_asyncio 
nest_asyncio.apply() 

load_dotenv()

os.environ.get("POSTGRES_DB")
# Out:
# 'test_lightrag'

# %%
WORKING_DIR = "../data/test_lightrag"

if not os.path.exists(WORKING_DIR):
    os.mkdir(WORKING_DIR)

# %%
from functools import wraps
import time

def rate_counter(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        if not hasattr(wrapper, 'call_count'):
            wrapper.call_count = 0
            wrapper.start_time = time.time()
        
        wrapper.call_count += 1
        wrapper.end_time = time.time()
        elapsed_time = wrapper.end_time - wrapper.start_time
        wrapper.rate = wrapper.call_count / (elapsed_time / 60)  # 次/分钟

        return func(*args, **kwargs)

    return wrapper

# %%
@rate_counter
async def test():
    print("1", end="")

# %%
import asyncio

# for i in range(100):
#     await test()
#     await asyncio.sleep(0.02)
test.start_time = time.time()
asyncio.gather(*[test() for i in range(100)])
    
print()
print(f"函数调用次数: {test.call_count}，总时间: {test.end_time - test.start_time}s，速率: {test.rate} 次/分钟")
# Out:
# 函数调用次数: 100，总时间: 0.00018787384033203125s，速率: 31936324.873096447 次/分钟

# %%
@rate_counter
async def llm_model_func(
    prompt, system_prompt=None, history_messages=[], **kwargs
) -> str:
    return await openai_complete_if_cache(
        "qwen-plus",
        prompt,
        system_prompt=system_prompt,
        history_messages=history_messages,
        api_key=os.getenv("DASHSCOPE_API_KEY"),
        base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
        **kwargs,
    )
# Out:
# 1111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111

# %%
from langchain_community.chat_models.tongyi import ChatTongyi
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from tenacity import retry, stop_after_attempt, wait_exponential

llm = ChatTongyi(model="qwen-plus")

@rate_counter
@retry(
    stop=stop_after_attempt(5),
    wait=wait_exponential(multiplier=1, min=4, max=20),
)
async def llm_model_func(
    prompt, system_prompt=None, history_messages=[], **kwargs
) -> str:
    messages = []
    if system_prompt:
        messages.append(SystemMessage(content=system_prompt))
    if history_messages:
        # for msg in history_messages:
        #     messages.append(HumanMessage(content=msg["content"]) if msg["role"] == "user" else AIMessage(content=msg["content"]))
        messages.extend([HumanMessage(content=msg["content"]) if msg["role"] == "user" else AIMessage(content=msg["content"]) for msg in history_messages])
    messages.append(HumanMessage(content=prompt))
    
    msg = await llm.ainvoke(messages)
    
    return msg.content

# %% [markdown]
# ### LightRAG

# %%
rag = LightRAG(
    working_dir=WORKING_DIR,
    workspace="test_lightrag",
    llm_model_func=llm_model_func,
    embedding_func=EmbeddingFunc(
        embedding_dim=1024,
        max_token_size=512,
        func=lambda texts: ollama_embedding(
            texts, embed_model="viosay/conan-embedding-v1:latest", host="http://192.168.69.234:11343"
        ),
    ),
    chunk_token_size=500,
    log_level="DEBUG",
    vector_storage="PostgresVectorDBStorage",
    graph_storage="Neo4JStorage"
)

# rag.vector_db_storage_cls.db = postgresql_db
# Out:
# INFO:lightrag:Logger initialized for working directory: ../data/test_lightrag
# DEBUG:lightrag:LightRAG init with param:
#   working_dir = ../data/test_lightrag,
#   workspace = test_lightrag,
#   kv_storage = JsonKVStorage,
#   vector_storage = PostgresVectorDBStorage,
#   graph_storage = Neo4JStorage,
#   log_level = DEBUG,
#   chunk_token_size = 500,
#   chunk_overlap_token_size = 100,
#   tiktoken_model_name = gpt-4o-mini,
#   entity_extract_max_gleaning = 1,
#   entity_summary_to_max_tokens = 500,
#   node_embedding_algorithm = node2vec,
#   node2vec_params = {'dimensions': 1536, 'num_walks': 10, 'walk_length': 40, 'window_size': 2, 'iterations': 3, 'random_seed': 3},
#   embedding_func = {'embedding_dim': 1024, 'max_token_size': 512, 'func': <function <lambda> at 0x7f974c264400>},
#   embedding_batch_num = 32,
#   embedding_func_max_async = 16,
#   llm_model_func = <function llm_model_func at 0x7f974ccd25c0>,
#   llm_model_name = meta-llama/Llama-3.2-1B-Instruct,
#   llm_model_max_token_size = 32768,
#   llm_model_max_async = 16,
#   llm_model_kwargs = {},
#   vector_db_storage_cls_kwargs = {},
#   enable_llm_cache = True,
#   addon_params = {},
#   convert_response_to_json_func = <function convert_response_to_json at 0x7f975367fa60>
#
# INFO:lightrag:Load KV llm_response_cache with 0 data
# INFO:lightrag:Load KV full_docs with 0 data
# INFO:lightrag:Load KV text_chunks with 0 data
# INFO:lightrag:Tables created successfully

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

doc_path = "../data/paper/scholat_paper_ed/scholat_paper_ed_001.csv"

loader = CSVLoader(doc_path)
data = loader.load()

data = [d.page_content for d in data]
need_to_insert_data = data[4:10]
need_to_insert_data
# Out:
# ['title: 基于WWW的交互式网络课件系统的开发技术\nauthors: 傅秀芬，汤庸\nsource: 计算机工程与应用\nsourceDetail: \ndate: 1998.-\ntype: 期刊论文\nkeyword: \nsummary: ',
#  'title: 时态变量“Now”语义及相应时态关系运算\nauthors: 叶小平，汤庸\nsource: 软件学报，2005，16（5）：838-845\nsourceDetail: \ndate: 2005.05\ntype: 期刊论文\nkeyword: \nsummary: ',
#  'title: 计算机支持的协同工作概观\nauthors: 汤庸\nsource: 工业工程,1999,2(003):10-12\nsourceDetail: \ndate: 1999.01\ntype: 期刊论文\nkeyword: \nsummary: ',
#  'title: 时态知识和时态数据的统一模型研究\nauthors: 汤庸，汤娜，叶小平，冯智圣，肖炜\nsource: 软件学报，2003，14(S),74-79 【EI】\nsourceDetail: \ndate: 2003.11\ntype: 期刊论文\nkeyword: \nsummary: ',
#  'title: 基于描述逻辑的CIM模型\nauthors: 蒋运承 汤庸 王驹 周生明\nsource: 微电子学与计算机,2007,24(012):55-58\nsourceDetail: \ndate: 2007.-\ntype: 期刊论文\nkeyword: \nsummary: ',
#  'title: CD—ROM信息存储与检索技术\nauthors: 汤庸\nsource: 计算机时代     1996年 第01期\nsourceDetail: \ndate: 1996.01\ntype: 期刊论文\nkeyword: \nsummary: ']

# %%
print(rag.entities_vdb)
print(rag.relationships_vdb)
print(rag.chunks_vdb)
# Out:
# EntityStorage(namespace='entities', global_config={'working_dir': '../data/test_lightrag', 'workspace': 'test_lightrag', 'kv_storage': 'JsonKVStorage', 'vector_storage': 'PostgresVectorDBStorage', 'graph_storage': 'Neo4JStorage', 'log_level': 'DEBUG', 'chunk_token_size': 500, 'chunk_overlap_token_size': 100, 'tiktoken_model_name': 'gpt-4o-mini', 'entity_extract_max_gleaning': 1, 'entity_summary_to_max_tokens': 500, 'node_embedding_algorithm': 'node2vec', 'node2vec_params': {'dimensions': 1536, 'num_walks': 10, 'walk_length': 40, 'window_size': 2, 'iterations': 3, 'random_seed': 3}, 'embedding_func': {'embedding_dim': 1024, 'max_token_size': 512, 'func': <function <lambda> at 0x7f974c264400>}, 'embedding_batch_num': 32, 'embedding_func_max_async': 16, 'llm_model_func': <function llm_model_func at 0x7f974ccd25c0>, 'llm_model_name': 'meta-llama/Llama-3.2-1B-Instruct', 'llm_model_max_token_size': 32768, 'llm_model_max_async': 16, 'llm_model_kwargs': {}, 'vector_db_storage_cls_kwargs': {}, 'enable_llm_cache': True, 'addon_params': {}, 'convert_response_to_json_func': <function convert_response_to_json at 0x7f975367fa60>}, embedding_func=EmbeddingFunc(embedding_dim=1024, max_token_size=512, func=<function <lambda> at 0x7f974c264400>), meta_fields=set())
# RelationshipStorage(namespace='relationships', global_config={'working_dir': '../data/test_lightrag', 'workspace': 'test_lightrag', 'kv_storage': 'JsonKVStorage', 'vector_storage': 'PostgresVectorDBStorage', 'graph_storage': 'Neo4JStorage', 'log_level': 'DEBUG', 'chunk_token_size': 500, 'chunk_overlap_token_size': 100, 'tiktoken_model_name': 'gpt-4o-mini', 'entity_extract_max_gleaning': 1, 'entity_summary_to_max_tokens': 500, 'node_embedding_algorithm': 'node2vec', 'node2vec_params': {'dimensions': 1536, 'num_walks': 10, 'walk_length': 40, 'window_size': 2, 'iterations': 3, 'random_seed': 3}, 'embedding_func': {'embedding_dim': 1024, 'max_token_size': 512, 'func': <function <lambda> at 0x7f974c264400>}, 'embedding_batch_num': 32, 'embedding_func_max_async': 16, 'llm_model_func': <function llm_model_func at 0x7f974ccd25c0>, 'llm_model_name': 'meta-llama/Llama-3.2-1B-Instruct', 'llm_model_max_token_size': 32768, 'llm_model_max_async': 16, 'llm_model_kwargs': {}, 'vector_db_storage_cls_kwargs': {}, 'enable_llm_cache': True, 'addon_params': {}, 'convert_response_to_json_func': <function convert_response_to_json at 0x7f975367fa60>}, embedding_func=EmbeddingFunc(embedding_dim=1024, max_token_size=512, func=<function <lambda> at 0x7f974c264400>), meta_fields=set())
# ChunkStorage(namespace='chunks', global_config={'working_dir': '../data/test_lightrag', 'workspace': 'test_lightrag', 'kv_storage': 'JsonKVStorage', 'vector_storage': 'PostgresVectorDBStorage', 'graph_storage': 'Neo4JStorage', 'log_level': 'DEBUG', 'chunk_token_size': 500, 'chunk_overlap_token_size': 100, 'tiktoken_model_name': 'gpt-4o-mini', 'entity_extract_max_gleaning': 1, 'entity_summary_to_max_tokens': 500, 'node_embedding_algorithm': 'node2vec', 'node2vec_params': {'dimensions': 1536, 'num_walks': 10, 'walk_length': 40, 'window_size': 2, 'iterations': 3, 'random_seed': 3}, 'embedding_func': {'embedding_dim': 1024, 'max_token_size': 512, 'func': <function <lambda> at 0x7f974c264400>}, 'embedding_batch_num': 32, 'embedding_func_max_async': 16, 'llm_model_func': <function llm_model_func at 0x7f974ccd25c0>, 'llm_model_name': 'meta-llama/Llama-3.2-1B-Instruct', 'llm_model_max_token_size': 32768, 'llm_model_max_async': 16, 'llm_model_kwargs': {}, 'vector_db_storage_cls_kwargs': {}, 'enable_llm_cache': True, 'addon_params': {}, 'convert_response_to_json_func': <function convert_response_to_json at 0x7f975367fa60>}, embedding_func=EmbeddingFunc(embedding_dim=1024, max_token_size=512, func=<function <lambda> at 0x7f974c264400>), meta_fields=set())

# %%
print(rag.vector_storage_cls)
# Out:
# <function PostgresStorageFactory.get_storage_class at 0x7f974d94ca40>

# %%
print(rag.entities_vdb.storage.engine.url)
# Out:
# postgresql+asyncpg://postgres:***@localhost:6024/test_lightrag

# %%
# await rag.entities_vdb.storage.init_tables()

# %%
await rag.ainsert(need_to_insert_data)
# Out:
# INFO:lightrag:[New Docs] inserting 6 docs
# INFO:lightrag:[New Chunks] inserting 6 chunks
# INFO:lightrag:[Entity Extraction]...
# ⠦ Processed 6 chunks, 37 entities(duplicated), 73 relations(duplicated)
# DEBUG:lightrag:Node 基于描述逻辑的CIM模型 is new to graph.
# DEBUG:lightrag:Original description tokens: 39
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 基于描述逻辑的CIM模型: 《基于描述逻辑的CIM模型》是一篇由蒋运承、汤庸、王驹、周生明共同撰写的期刊论文。
# DEBUG:lightrag:Node 肖炜 is new to graph.
# DEBUG:lightrag:Original description tokens: 24
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 肖炜: 肖炜是该论文的作者之一，对时态知识和时态数据的统一模型研究有所贡献。
# DEBUG:lightrag:Node 计算机工程与应用 is new to graph.
# DEBUG:lightrag:Original description tokens: 33
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 计算机工程与应用: 计算机工程与应用是一份学术期刊，发表了《基于WWW的交互式网络课件系统的开发技术》一文。
# DEBUG:lightrag:Node 1996年 第01期 is new to graph.
# DEBUG:lightrag:Original description tokens: 21
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 1996年 第01期: 这是《计算机时代》发布论文的具体日期，标志着该研究的时间点。
# DEBUG:lightrag:Node 1996.01 is new to graph.
# DEBUG:lightrag:Original description tokens: 17
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 1996.01: 这是论文发表的确切日期，进一步确认了研究的时间框架。
# DEBUG:lightrag:Node 2007年 is new to graph.
# DEBUG:lightrag:Original description tokens: 20
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 2007年: 2007年是论文《基于描述逻辑的CIM模型》发表的年份。
# DEBUG:lightrag:Node 2003.11 is new to graph.
# DEBUG:lightrag:Original description tokens: 23
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 2003.11: 2003年11月是论文《时态知识和时态数据的统一模型研究》的发表时间。
# DEBUG:lightrag:Node 王驹 is new to graph.
# DEBUG:lightrag:Original description tokens: 19
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 王驹: 王驹是论文《基于描述逻辑的CIM模型》的作者之一。
# DEBUG:lightrag:Node 冯智圣 is new to graph.
# DEBUG:lightrag:Original description tokens: 25
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 冯智圣: 冯智圣是该论文的作者之一，参与了时态知识和时态数据的统一模型研究。
# DEBUG:lightrag:Node 时态知识和时态数据的统一模型研究 is new to graph.
# DEBUG:lightrag:Original description tokens: 27
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 时态知识和时态数据的统一模型研究: 这是一篇研究时态知识和时态数据统一模型的学术论文，由汤庸等人撰写。
# DEBUG:lightrag:Node 软件学报 is new to graph.
# DEBUG:lightrag:Original description tokens: 59
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 软件学报: 软件学报是一份学术期刊，发表了关于时态知识和时态数据的统一模型研究的论文。<SEP>软件学报是一份学术期刊，发表了叶小平和汤庸关于时态变量‘Now’的研究。
# DEBUG:lightrag:Node 2005.05 is new to graph.
# DEBUG:lightrag:Original description tokens: 29
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 2005.05: 2005年5月是论文《时态变量‘Now’语义及相应时态关系运算》发表的时间。
# DEBUG:lightrag:Node 计算机时代 is new to graph.
# DEBUG:lightrag:Original description tokens: 24
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 计算机时代: 《计算机时代》是一本出版了关于CD-ROM信息存储与检索技术论文的期刊。
# DEBUG:lightrag:Node 汤庸 is new to graph.
# DEBUG:lightrag:Original description tokens: 152
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 汤庸: 汤庸是《基于WWW的交互式网络课件系统的开发技术》的另一位作者。<SEP>汤庸是论文《基于描述逻辑的CIM模型》的作者之一。<SEP>汤庸是论文《时态变量‘Now’语义及相应时态关系运算》的另一位作者。<SEP>汤庸是该论文的作者之一，专注于时态知识和时态数据的统一模型研究。<SEP>汤庸是这篇关于CD-ROM信息存储与检索技术论文的作者。<SEP>汤庸是这篇论文的作者，专注于计算机支持的协同工作领域。
# DEBUG:lightrag:Node 基于WWW的交互式网络课件系统的开发技术 is new to graph.
# DEBUG:lightrag:Original description tokens: 20
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 基于WWW的交互式网络课件系统的开发技术: 这是一篇关于开发基于Web的交互式网络课件系统的技术论文。
# DEBUG:lightrag:Node CD—ROM信息存储与检索技术 is new to graph.
# DEBUG:lightrag:Original description tokens: 26
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for CD—ROM信息存储与检索技术: 这是一篇探讨CD-ROM信息存储与检索技术的学术论文，由汤庸撰写。
# DEBUG:lightrag:Node 工业工程 is new to graph.
# DEBUG:lightrag:Original description tokens: 21
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 工业工程: 工业工程是一本学术期刊，发表了关于计算机支持的协同工作的论文。
# DEBUG:lightrag:Node 时态变量‘NOW’语义及相应时态关系运算 is new to graph.
# DEBUG:lightrag:Original description tokens: 37
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 时态变量‘NOW’语义及相应时态关系运算: 这是一篇探讨时态变量‘Now’的语义及其时态关系运算的学术论文，由叶小平和汤庸撰写。
# DEBUG:lightrag:Node 1998. is new to graph.
# DEBUG:lightrag:Original description tokens: 21
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 1998.: 这是论文《基于WWW的交互式网络课件系统的开发技术》的发表日期。
# DEBUG:lightrag:Node 微电子学与计算机 is new to graph.
# DEBUG:lightrag:Original description tokens: 29
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 微电子学与计算机: 《微电子学与计算机》是一份学术期刊，发表了论文《基于描述逻辑的CIM模型》。
# DEBUG:lightrag:Node 傅秀芬 is new to graph.
# DEBUG:lightrag:Original description tokens: 23
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 傅秀芬: 傅秀芬是《基于WWW的交互式网络课件系统的开发技术》的作者之一。
# DEBUG:lightrag:Node 计算机支持的协同工作概观 is new to graph.
# DEBUG:lightrag:Original description tokens: 22
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 计算机支持的协同工作概观: 这是一篇关于计算机支持的协同工作的综述论文，由汤庸撰写。
# DEBUG:lightrag:Node 1999.01 is new to graph.
# DEBUG:lightrag:Original description tokens: 15
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 1999.01: 论文发表的具体日期，标志着该研究的时间点。
# DEBUG:lightrag:Node 叶小平 is new to graph.
# DEBUG:lightrag:Original description tokens: 53
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 叶小平: 叶小平是论文《时态变量‘Now’语义及相应时态关系运算》的作者之一。<SEP>叶小平是该论文的作者之一，贡献了时态知识和时态数据的统一模型研究。
# DEBUG:lightrag:Node 期刊论文 is new to graph.
# DEBUG:lightrag:Original description tokens: 71
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 期刊论文: 期刊论文是指发表在学术期刊上的研究论文。<SEP>期刊论文是指在学术期刊上发表的研究成果，本例中指《时态知识和时态数据的统一模型研究》。<SEP>论文的类型，指明其属于学术出版物中的期刊论文类别。
# DEBUG:lightrag:Node 汤娜 is new to graph.
# DEBUG:lightrag:Original description tokens: 23
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 汤娜: 汤娜是该论文的作者之一，参与了时态知识和时态数据的统一模型研究。
# DEBUG:lightrag:Node 蒋运承 is new to graph.
# DEBUG:lightrag:Original description tokens: 20
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 蒋运承: 蒋运承是论文《基于描述逻辑的CIM模型》的作者之一。
# DEBUG:lightrag:Node 周生明 is new to graph.
# DEBUG:lightrag:Original description tokens: 19
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for 周生明: 周生明是论文《基于描述逻辑的CIM模型》的作者之一。
# DEBUG:lightrag:Upserted node with id '1996年 第01期', label 'DATE' and properties: {'entity_type': 'DATE', 'description': '这是《计算机时代》发布论文的具体日期，标志着该研究的时间点。', 'source_id': 'chunk-7ee1d44c4e5eac0bbcba30cea0223dd9', 'displayName': '1996年 第01期'}
# DEBUG:lightrag:Upserted node with id '2007年', label 'DATE' and properties: {'entity_type': 'DATE', 'description': '2007年是论文《基于描述逻辑的CIM模型》发表的年份。', 'source_id': 'chunk-7061677a44e71bde3b7d8f5c3bebb5ee', 'displayName': '2007年'}
# DEBUG:lightrag:Upserted node with id '2003.11', label 'DATE' and properties: {'entity_type': 'DATE', 'description': '2003年11月是论文《时态知识和时态数据的统一模型研究》的发表时间。', 'source_id': 'chunk-73f68d1cc6f8d7d1f23ed5eea890ca32', 'displayName': '2003.11'}
# DEBUG:lightrag:Upserted node with id '肖炜', label 'PERSON' and properties: {'entity_type': 'PERSON', 'description': '肖炜是该论文的作者之一，对时态知识和时态数据的统一模型研究有所贡献。', 'source_id': 'chunk-73f68d1cc6f8d7d1f23ed5eea890ca32', 'displayName': '肖炜'}
# DEBUG:lightrag:Upserted node with id '王驹', label 'PERSON' and properties: {'entity_type': 'PERSON', 'description': '王驹是论文《基于描述逻辑的CIM模型》的作者之一。', 'source_id': 'chunk-7061677a44e71bde3b7d8f5c3bebb5ee', 'displayName': '王驹'}
# DEBUG:lightrag:Upserted node with id '基于描述逻辑的CIM模型', label 'PAPER' and properties: {'entity_type': 'PAPER', 'description': '《基于描述逻辑的CIM模型》是一篇由蒋运承、汤庸、王驹、周生明共同撰写的期刊论文。', 'source_id': 'chunk-7061677a44e71bde3b7d8f5c3bebb5ee', 'displayName': '基于描述逻辑的CIM模型'}
# DEBUG:lightrag:Upserted node with id '计算机工程与应用', label 'JOURNAL' and properties: {'entity_type': 'JOURNAL', 'description': '计算机工程与应用是一份学术期刊，发表了《基于WWW的交互式网络课件系统的开发技术》一文。', 'source_id': 'chunk-c3ddc19663e979c22961236d629d7faa', 'displayName': '计算机工程与应用'}
# DEBUG:lightrag:Upserted node with id '2005.05', label 'DATE' and properties: {'entity_type': 'DATE', 'description': '2005年5月是论文《时态变量‘Now’语义及相应时态关系运算》发表的时间。', 'source_id': 'chunk-49dcb89e79b16caced258e08371122e5', 'displayName': '2005.05'}
# DEBUG:lightrag:Upserted node with id 'CD—ROM信息存储与检索技术', label 'PAPER' and properties: {'entity_type': 'PAPER', 'description': '这是一篇探讨CD-ROM信息存储与检索技术的学术论文，由汤庸撰写。', 'source_id': 'chunk-7ee1d44c4e5eac0bbcba30cea0223dd9', 'displayName': 'CD—ROM信息存储与检索技术'}
# DEBUG:lightrag:Upserted node with id '软件学报', label 'JOURNAL' and properties: {'entity_type': 'JOURNAL', 'description': '软件学报是一份学术期刊，发表了关于时态知识和时态数据的统一模型研究的论文。<SEP>软件学报是一份学术期刊，发表了叶小平和汤庸关于时态变量‘Now’的研究。', 'source_id': 'chunk-73f68d1cc6f8d7d1f23ed5eea890ca32<SEP>chunk-49dcb89e79b16caced258e08371122e5', 'displayName': '软件学报'}
# DEBUG:lightrag:Upserted node with id '工业工程', label 'JOURNAL' and properties: {'entity_type': 'JOURNAL', 'description': '工业工程是一本学术期刊，发表了关于计算机支持的协同工作的论文。', 'source_id': 'chunk-52c7b60eb2f46bca990151794d9339c5', 'displayName': '工业工程'}
# DEBUG:lightrag:Upserted node with id '1996.01', label 'DATE' and properties: {'entity_type': 'DATE', 'description': '这是论文发表的确切日期，进一步确认了研究的时间框架。', 'source_id': 'chunk-7ee1d44c4e5eac0bbcba30cea0223dd9', 'displayName': '1996.01'}
# DEBUG:lightrag:Upserted node with id '冯智圣', label 'PERSON' and properties: {'entity_type': 'PERSON', 'description': '冯智圣是该论文的作者之一，参与了时态知识和时态数据的统一模型研究。', 'source_id': 'chunk-73f68d1cc6f8d7d1f23ed5eea890ca32', 'displayName': '冯智圣'}
# DEBUG:lightrag:Upserted node with id '汤娜', label 'PERSON' and properties: {'entity_type': 'PERSON', 'description': '汤娜是该论文的作者之一，参与了时态知识和时态数据的统一模型研究。', 'source_id': 'chunk-73f68d1cc6f8d7d1f23ed5eea890ca32', 'displayName': '汤娜'}
# DEBUG:lightrag:Upserted node with id '计算机时代', label 'JOURNAL' and properties: {'entity_type': 'JOURNAL', 'description': '《计算机时代》是一本出版了关于CD-ROM信息存储与检索技术论文的期刊。', 'source_id': 'chunk-7ee1d44c4e5eac0bbcba30cea0223dd9', 'displayName': '计算机时代'}
# DEBUG:lightrag:Upserted node with id '基于WWW的交互式网络课件系统的开发技术', label 'PAPER' and properties: {'entity_type': 'PAPER', 'description': '这是一篇关于开发基于Web的交互式网络课件系统的技术论文。', 'source_id': 'chunk-c3ddc19663e979c22961236d629d7faa', 'displayName': '基于WWW的交互式网络课件系统的开发技术'}
# DEBUG:lightrag:Upserted node with id '蒋运承', label 'PERSON' and properties: {'entity_type': 'PERSON', 'description': '蒋运承是论文《基于描述逻辑的CIM模型》的作者之一。', 'source_id': 'chunk-7061677a44e71bde3b7d8f5c3bebb5ee', 'displayName': '蒋运承'}
# DEBUG:lightrag:Upserted node with id '汤庸', label 'PERSON' and properties: {'entity_type': 'PERSON', 'description': '汤庸是《基于WWW的交互式网络课件系统的开发技术》的另一位作者。<SEP>汤庸是论文《基于描述逻辑的CIM模型》的作者之一。<SEP>汤庸是论文《时态变量‘Now’语义及相应时态关系运算》的另一位作者。<SEP>汤庸是该论文的作者之一，专注于时态知识和时态数据的统一模型研究。<SEP>汤庸是这篇关于CD-ROM信息存储与检索技术论文的作者。<SEP>汤庸是这篇论文的作者，专注于计算机支持的协同工作领域。', 'source_id': 'chunk-7061677a44e71bde3b7d8f5c3bebb5ee<SEP>chunk-73f68d1cc6f8d7d1f23ed5eea890ca32<SEP>chunk-52c7b60eb2f46bca990151794d9339c5<SEP>chunk-49dcb89e79b16caced258e08371122e5<SEP>chunk-7ee1d44c4e5eac0bbcba30cea0223dd9<SEP>chunk-c3ddc19663e979c22961236d629d7faa', 'displayName': '汤庸'}
# DEBUG:lightrag:Upserted node with id '1998.', label 'DATE' and properties: {'entity_type': 'DATE', 'description': '这是论文《基于WWW的交互式网络课件系统的开发技术》的发表日期。', 'source_id': 'chunk-c3ddc19663e979c22961236d629d7faa', 'displayName': '1998.'}
# DEBUG:lightrag:Upserted node with id '计算机支持的协同工作概观', label 'PAPER' and properties: {'entity_type': 'PAPER', 'description': '这是一篇关于计算机支持的协同工作的综述论文，由汤庸撰写。', 'source_id': 'chunk-52c7b60eb2f46bca990151794d9339c5', 'displayName': '计算机支持的协同工作概观'}
# DEBUG:lightrag:Upserted node with id '时态变量‘NOW’语义及相应时态关系运算', label 'PAPER' and properties: {'entity_type': 'PAPER', 'description': '这是一篇探讨时态变量‘Now’的语义及其时态关系运算的学术论文，由叶小平和汤庸撰写。', 'source_id': 'chunk-49dcb89e79b16caced258e08371122e5', 'displayName': '时态变量‘NOW’语义及相应时态关系运算'}
# DEBUG:lightrag:Upserted node with id '傅秀芬', label 'PERSON' and properties: {'entity_type': 'PERSON', 'description': '傅秀芬是《基于WWW的交互式网络课件系统的开发技术》的作者之一。', 'source_id': 'chunk-c3ddc19663e979c22961236d629d7faa', 'displayName': '傅秀芬'}
# DEBUG:lightrag:Upserted node with id '微电子学与计算机', label 'JOURNAL' and properties: {'entity_type': 'JOURNAL', 'description': '《微电子学与计算机》是一份学术期刊，发表了论文《基于描述逻辑的CIM模型》。', 'source_id': 'chunk-7061677a44e71bde3b7d8f5c3bebb5ee', 'displayName': '微电子学与计算机'}
# DEBUG:lightrag:Upserted node with id '1999.01', label 'DATE' and properties: {'entity_type': 'DATE', 'description': '论文发表的具体日期，标志着该研究的时间点。', 'source_id': 'chunk-52c7b60eb2f46bca990151794d9339c5', 'displayName': '1999.01'}
# DEBUG:lightrag:Upserted node with id '叶小平', label 'PERSON' and properties: {'entity_type': 'PERSON', 'description': '叶小平是论文《时态变量‘Now’语义及相应时态关系运算》的作者之一。<SEP>叶小平是该论文的作者之一，贡献了时态知识和时态数据的统一模型研究。', 'source_id': 'chunk-73f68d1cc6f8d7d1f23ed5eea890ca32<SEP>chunk-49dcb89e79b16caced258e08371122e5', 'displayName': '叶小平'}
# DEBUG:lightrag:Upserted node with id '周生明', label 'PERSON' and properties: {'entity_type': 'PERSON', 'description': '周生明是论文《基于描述逻辑的CIM模型》的作者之一。', 'source_id': 'chunk-7061677a44e71bde3b7d8f5c3bebb5ee', 'displayName': '周生明'}
# DEBUG:lightrag:Upserted node with id '时态知识和时态数据的统一模型研究', label 'PAPER' and properties: {'entity_type': 'PAPER', 'description': '这是一篇研究时态知识和时态数据统一模型的学术论文，由汤庸等人撰写。', 'source_id': 'chunk-73f68d1cc6f8d7d1f23ed5eea890ca32', 'displayName': '时态知识和时态数据的统一模型研究'}
# DEBUG:lightrag:Upserted node 肖炜 into knowledge graph.
# DEBUG:lightrag:Upserted node 1996年 第01期 into knowledge graph.
# DEBUG:lightrag:Upserted node 2007年 into knowledge graph.
# DEBUG:lightrag:Upserted node 2003.11 into knowledge graph.
# DEBUG:lightrag:Upserted node with id '期刊论文', label 'TYPE' and properties: {'entity_type': 'TYPE', 'description': '期刊论文是指发表在学术期刊上的研究论文。<SEP>期刊论文是指在学术期刊上发表的研究成果，本例中指《时态知识和时态数据的统一模型研究》。<SEP>论文的类型，指明其属于学术出版物中的期刊论文类别。', 'source_id': 'chunk-52c7b60eb2f46bca990151794d9339c5<SEP>chunk-7061677a44e71bde3b7d8f5c3bebb5ee<SEP>chunk-73f68d1cc6f8d7d1f23ed5eea890ca32', 'displayName': '期刊论文'}
# DEBUG:lightrag:Upserted node 王驹 into knowledge graph.
# DEBUG:lightrag:Upserted node 基于描述逻辑的CIM模型 into knowledge graph.
# DEBUG:lightrag:Upserted node 计算机工程与应用 into knowledge graph.
# DEBUG:lightrag:Upserted node 2005.05 into knowledge graph.
# DEBUG:lightrag:Upserted node CD—ROM信息存储与检索技术 into knowledge graph.
# DEBUG:lightrag:Upserted node 工业工程 into knowledge graph.
# DEBUG:lightrag:Upserted node 软件学报 into knowledge graph.
# DEBUG:lightrag:Upserted node 1996.01 into knowledge graph.
# DEBUG:lightrag:Upserted node 冯智圣 into knowledge graph.
# DEBUG:lightrag:Upserted node 汤娜 into knowledge graph.
# DEBUG:lightrag:Upserted node 计算机时代 into knowledge graph.
# DEBUG:lightrag:Upserted node 基于WWW的交互式网络课件系统的开发技术 into knowledge graph.
# DEBUG:lightrag:Upserted node 蒋运承 into knowledge graph.
# DEBUG:lightrag:Upserted node 汤庸 into knowledge graph.
# DEBUG:lightrag:Upserted node 1998. into knowledge graph.
# DEBUG:lightrag:Upserted node 计算机支持的协同工作概观 into knowledge graph.
# DEBUG:lightrag:Upserted node 时态变量‘NOW’语义及相应时态关系运算 into knowledge graph.
# DEBUG:lightrag:Upserted node 傅秀芬 into knowledge graph.
# DEBUG:lightrag:Upserted node 微电子学与计算机 into knowledge graph.
# DEBUG:lightrag:Upserted node 1999.01 into knowledge graph.
# DEBUG:lightrag:Upserted node 叶小平 into knowledge graph.
# DEBUG:lightrag:Upserted node 周生明 into knowledge graph.
# DEBUG:lightrag:Upserted node 时态知识和时态数据的统一模型研究 into knowledge graph.
# DEBUG:lightrag:Upserted node 期刊论文 into knowledge graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 工业工程 to 计算机支持的协同工作概观 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 期刊论文 to 计算机支持的协同工作概观 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 1999.01 to 期刊论文 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 1999.01 to 计算机支持的协同工作概观 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 时态变量‘NOW’语义及相应时态关系运算 to 汤庸 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 工业工程 to 汤庸 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 1998. to 基于WWW的交互式网络课件系统的开发技术 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 2005.05 to 软件学报 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 叶小平 to 时态变量‘NOW’语义及相应时态关系运算 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 基于WWW的交互式网络课件系统的开发技术 to 计算机工程与应用 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 时态变量‘NOW’语义及相应时态关系运算 to 软件学报 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 2005.05 to 汤庸 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 时态知识和时态数据的统一模型研究 to 汤庸 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 汤庸 to 计算机支持的协同工作概观 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 傅秀芬 to 基于WWW的交互式网络课件系统的开发技术 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 汤庸 to 计算机工程与应用 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 1998. to 计算机工程与应用 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 基于WWW的交互式网络课件系统的开发技术 to 汤庸 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 叶小平 to 软件学报 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 工业工程 to 期刊论文 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 1999.01 to 工业工程 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 傅秀芬 to 汤庸 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 傅秀芬 to 计算机工程与应用 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 汤庸 to 软件学报 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 2005.05 to 叶小平 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 时态知识和时态数据的统一模型研究 to 汤娜 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 2005.05 to 时态变量‘NOW’语义及相应时态关系运算 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 期刊论文 to 汤庸 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 叶小平 to 时态知识和时态数据的统一模型研究 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 冯智圣 to 时态知识和时态数据的统一模型研究 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 时态知识和时态数据的统一模型研究 to 肖炜 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 时态知识和时态数据的统一模型研究 to 软件学报 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 2003.11 to 时态知识和时态数据的统一模型研究 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 时态知识和时态数据的统一模型研究 to 期刊论文 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 汤娜 to 软件学报 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 冯智圣 to 软件学报 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 肖炜 to 软件学报 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 2003.11 to 汤庸 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 2003.11 to 汤娜 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 2003.11 to 叶小平 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 2003.11 to 冯智圣 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 2003.11 to 肖炜 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 期刊论文 to 汤娜 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 叶小平 to 期刊论文 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 冯智圣 to 期刊论文 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 期刊论文 to 肖炜 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 基于描述逻辑的CIM模型 to 蒋运承 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 基于描述逻辑的CIM模型 to 汤庸 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 基于描述逻辑的CIM模型 to 王驹 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 周生明 to 基于描述逻辑的CIM模型 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 基于描述逻辑的CIM模型 to 微电子学与计算机 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 2007年 to 基于描述逻辑的CIM模型 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 基于描述逻辑的CIM模型 to 期刊论文 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 微电子学与计算机 to 蒋运承 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 微电子学与计算机 to 汤庸 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 微电子学与计算机 to 王驹 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 周生明 to 微电子学与计算机 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 2007年 to 微电子学与计算机 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 2007年 to 期刊论文 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from CD—ROM信息存储与检索技术 to 汤庸 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from CD—ROM信息存储与检索技术 to 计算机时代 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 1996年 第01期 to CD—ROM信息存储与检索技术 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 汤庸 to 计算机时代 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 1996年 第01期 to 汤庸 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 1996.01 to 汤庸 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 1996年 第01期 to 计算机时代 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 1996.01 to 计算机时代 is new to graph.
# DEBUG:lightrag:has_edge:query:MATCH (a {displayName: $entity_name_source})-[r]-(b {displayName: $entity_name_target}) RETURN COUNT(r) > 0 AS edgeExists:result:False
# DEBUG:lightrag:Edge from 1996.01 to 1996年 第01期 is new to graph.
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 30
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 工业工程->计算机支持的协同工作概观: 论文《计算机支持的协同工作概观》发表在《工业工程》期刊上，表明了论文的出版平台。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 25
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 期刊论文->计算机支持的协同工作概观: 论文《计算机支持的协同工作概观》是一篇期刊论文，强调了其学术性质。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 30
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 1999.01->期刊论文: 1999年1月是期刊论文《计算机支持的协同工作概观》的发表时间，强调了研究的时间定位。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 47
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 时态变量‘NOW’语义及相应时态关系运算->汤庸: 汤庸是该论文的共同作者，与叶小平一起完成了这项研究。<SEP>该论文由汤庸共同撰写，展示了他在时态逻辑领域的研究能力。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 24
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 1998.->基于WWW的交互式网络课件系统的开发技术: 论文《基于WWW的交互式网络课件系统的开发技术》是在1998年发表的。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 26
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 1999.01->计算机支持的协同工作概观: 论文《计算机支持的协同工作概观》发表于1999年1月，指出了研究的时间背景。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 29
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 工业工程->汤庸: 《工业工程》期刊发表了汤庸的研究成果，表明了作者与期刊之间的学术合作关系。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 31
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 2005.05->软件学报: 软件学报在2005年5月发表了叶小平和汤庸的研究成果，体现了期刊的学术动态。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 13
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 基于WWW的交互式网络课件系统的开发技术->计算机工程与应用: 计算机工程与应用期刊发表了这篇论文。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 46
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 叶小平->时态变量‘NOW’语义及相应时态关系运算: 叶小平是该论文的主要作者之一，对该研究做出了贡献。<SEP>该论文由叶小平共同撰写，反映了他在时态逻辑领域的研究深度。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 24
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 时态变量‘NOW’语义及相应时态关系运算->软件学报: 这篇论文发表在软件学报上，表明该期刊对时态逻辑研究的认可。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 25
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 2005.05->汤庸: 汤庸的研究成果同样在2005年5月发表，反映了这一时期的合作研究。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 18
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 时态知识和时态数据的统一模型研究->汤庸: 汤庸是该论文的主要作者之一，对该研究做出了重要贡献。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 28
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 汤庸->计算机支持的协同工作概观: 汤庸是论文《计算机支持的协同工作概观》的作者，展示了他在该领域的研究贡献。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 11
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 傅秀芬->基于WWW的交互式网络课件系统的开发技术: 傅秀芬是该论文的共同作者之一。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 19
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 汤庸->计算机工程与应用: 汤庸的研究成果发表在《计算机工程与应用》期刊上。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 31
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 1998.->计算机工程与应用: 《计算机工程与应用》期刊在1998年发表了《基于WWW的交互式网络课件系统的开发技术》。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 11
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 基于WWW的交互式网络课件系统的开发技术->汤庸: 汤庸是该论文的共同作者之一。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 48
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 叶小平->软件学报: 叶小平是论文的共同作者之一，论文发表在《软件学报》上。<SEP>叶小平的研究成果在软件学报上发表，表明他在该领域的学术地位。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 26
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 工业工程->期刊论文: 《工业工程》是一本发布期刊论文的学术期刊，强调了其在学术交流中的角色。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 25
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 1999.01->工业工程: 《工业工程》期刊在1999年1月发表了相关论文，指出了期刊的出版时间。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 28
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 傅秀芬->汤庸: 傅秀芬和汤庸合作撰写了《基于WWW的交互式网络课件系统的开发技术》。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 19
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 傅秀芬->计算机工程与应用: 傅秀芬的研究成果发表在《计算机工程与应用》期刊上。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 47
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 汤庸->软件学报: 汤庸是论文的主要作者之一，论文发表在《软件学报》上。<SEP>汤庸的研究成果也在软件学报上发表，显示了他对学术界的贡献。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 23
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 2005.05->叶小平: 叶小平的研究成果在2005年5月发表，标志着这一时期的研究成果。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 22
# DEBUG:lightrag:Description is short enough, no need to summarize.
# DEBUG:lightrag:Final description for edge 时态知识和时态数据的统一模型研究->汤娜: 汤娜作为论文的共同作者，参与了时态知识和时态数据的统一模型研究。
# DEBUG:lightrag:has_node:query:MATCH (n {displayName: $displayName}) RETURN count(n) > 0 AS node_exists:result:True
# DEBUG:lightrag:Original description tokens: 71
# ...
# DEBUG:lightrag:[upserting relationship] {'rel-fa7ac990cced4f7f9c0c5a017c6c982e': {'src_id': '傅秀芬', 'tgt_id': '基于WWW的交互式网络课件系统的开发技术', 'content': '作者, 研究贡献傅秀芬基于WWW的交互式网络课件系统的开发技术傅秀芬是该论文的共同作者之一。'}, 'rel-11c168b313681f3e2a9c0e6edae6da4f': {'src_id': '基于WWW的交互式网络课件系统的开发技术', 'tgt_id': '汤庸', 'content': '作者, 研究贡献基于WWW的交互式网络课件系统的开发技术汤庸汤庸是该论文的共同作者之一。'}, 'rel-a57844a93da9be6e73750256a37baf37': {'src_id': '基于WWW的交互式网络课件系统的开发技术', 'tgt_id': '计算机工程与应用', 'content': '出版, 学术贡献基于WWW的交互式网络课件系统的开发技术计算机工程与应用计算机工程与应用期刊发表了这篇论文。'}, 'rel-ef182b3b7ba848c0d991bf8893ead1ee': {'src_id': '1998.', 'tgt_id': '基于WWW的交互式网络课件系统的开发技术', 'content': '时间关联, 学术记录1998.基于WWW的交互式网络课件系统的开发技术论文《基于WWW的交互式网络课件系统的开发技术》是在1998年发表的。'}, 'rel-4298796f1eeacf3a6223e640c3d3d2dc': {'src_id': '傅秀芬', 'tgt_id': '计算机工程与应用', 'content': '作者-期刊关系, 学术发表傅秀芬计算机工程与应用傅秀芬的研究成果发表在《计算机工程与应用》期刊上。'}, 'rel-414f78e21f942ab16948feebbbea4ee6': {'src_id': '汤庸', 'tgt_id': '计算机工程与应用', 'content': '作者-期刊关系, 学术发表汤庸计算机工程与应用汤庸的研究成果发表在《计算机工程与应用》期刊上。'}, 'rel-7c150a456651f03f283f5938ebe9e78a': {'src_id': '傅秀芬', 'tgt_id': '汤庸', 'content': '合作, 学术研究傅秀芬汤庸傅秀芬和汤庸合作撰写了《基于WWW的交互式网络课件系统的开发技术》。'}, 'rel-b14ed6f52c13e34e9934e5ff528b1e87': {'src_id': '1998.', 'tgt_id': '计算机工程与应用', 'content': '出版时间, 学术记录1998.计算机工程与应用《计算机工程与应用》期刊在1998年发表了《基于WWW的交互式网络课件系统的开发技术》。'}, 'rel-46b7058c7c950bf5cbb0ed064961f05b': {'src_id': '叶小平', 'tgt_id': '时态变量‘NOW’语义及相应时态关系运算', 'content': '作者, 研究贡献<SEP>研究贡献, 学术作品叶小平时态变量‘NOW’语义及相应时态关系运算叶小平是该论文的主要作者之一，对该研究做出了贡献。<SEP>该论文由叶小平共同撰写，反映了他在时态逻辑领域的研究深度。'}, 'rel-ad3a3154cbdfab331c5589dac95ef450': {'src_id': '时态变量‘NOW’语义及相应时态关系运算', 'tgt_id': '汤庸', 'content': '共同作者, 研究合作<SEP>研究贡献, 学术作品时态变量‘NOW’语义及相应时态关系运算汤庸汤庸是该论文的共同作者，与叶小平一起完成了这项研究。<SEP>该论文由汤庸共同撰写，展示了他在时态逻辑领域的研究能力。'}, 'rel-d2618371612ef5edbf3aa2b67e15de51': {'src_id': '时态变量‘NOW’语义及相应时态关系运算', 'tgt_id': '软件学报', 'content': '出版, 学术认可时态变量‘NOW’语义及相应时态关系运算软件学报这篇论文发表在软件学报上，表明该期刊对时态逻辑研究的认可。'}, 'rel-8c9a9d8c08ba2cb53f81b048bb6a8eee': {'src_id': '2005.05', 'tgt_id': '时态变量‘NOW’语义及相应时态关系运算', 'content': '时间关联, 出版日期2005.05时态变量‘NOW’语义及相应时态关系运算论文《时态变量‘Now’语义及相应时态关系运算》在2005年5月发表，指出了研究的时间点。<SEP>论文《时态变量‘Now’语义及相应时态关系运算》在2005年5月发表，确定了研究的时间点。'}, 'rel-7aa6da2d47b95f0aa3518f1f76c373ca': {'src_id': '叶小平', 'tgt_id': '软件学报', 'content': '发表平台, 作者贡献<SEP>学术贡献, 发表平台叶小平软件学报叶小平是论文的共同作者之一，论文发表在《软件学报》上。<SEP>叶小平的研究成果在软件学报上发表，表明他在该领域的学术地位。'}, 'rel-cff4bc631d899ecdc1e7b7e912ab0e28': {'src_id': '汤庸', 'tgt_id': '软件学报', 'content': '发表平台, 作者贡献<SEP>学术贡献, 发表平台汤庸软件学报汤庸是论文的主要作者之一，论文发表在《软件学报》上。<SEP>汤庸的研究成果也在软件学报上发表，显示了他对学术界的贡献。'}, 'rel-405fedf8bcede4945797dd4e2429a0e4': {'src_id': '2005.05', 'tgt_id': '叶小平', 'content': '时间关联, 学术活动2005.05叶小平叶小平的研究成果在2005年5月发表，标志着这一时期的研究成果。'}, 'rel-06b2c8e406c289f5898745a400ba7a0f': {'src_id': '2005.05', 'tgt_id': '汤庸', 'content': '时间关联, 学术活动2005.05汤庸汤庸的研究成果同样在2005年5月发表，反映了这一时期的合作研究。'}, 'rel-caa2ead67d1855d830fdd4ea5f81d0a2': {'src_id': '2005.05', 'tgt_id': '软件学报', 'content': '时间关联, 学术发布2005.05软件学报软件学报在2005年5月发表了叶小平和汤庸的研究成果，体现了期刊的学术动态。'}, 'rel-555c6eecc349bdffbfb721cad798fc48': {'src_id': '汤庸', 'tgt_id': '计算机支持的协同工作概观', 'content': '作者, 研究贡献汤庸计算机支持的协同工作概观汤庸是论文《计算机支持的协同工作概观》的作者，展示了他在该领域的研究贡献。'}, 'rel-afc7804ab4c58646b6872fb90b218358': {'src_id': '工业工程', 'tgt_id': '计算机支持的协同工作概观', 'content': '出版, 学术交流工业工程计算机支持的协同工作概观论文《计算机支持的协同工作概观》发表在《工业工程》期刊上，表明了论文的出版平台。'}, 'rel-309acc2c356666d070c6a3c5e59a3d92': {'src_id': '1999.01', 'tgt_id': '计算机支持的协同工作概观', 'content': '时间背景, 发表日期1999.01计算机支持的协同工作概观论文《计算机支持的协同工作概观》发表于1999年1月，指出了研究的时间背景。'}, 'rel-60dcff84e306127bc7c279b6a6b944a0': {'src_id': '期刊论文', 'tgt_id': '计算机支持的协同工作概观', 'content': '学术性质, 出版类型期刊论文计算机支持的协同工作概观论文《计算机支持的协同工作概观》是一篇期刊论文，强调了其学术性质。'}, 'rel-4d76215a2b2cfee0207757f2129ca4ce': {'src_id': '工业工程', 'tgt_id': '汤庸', 'content': '学术合作, 出版平台工业工程汤庸《工业工程》期刊发表了汤庸的研究成果，表明了作者与期刊之间的学术合作关系。'}, 'rel-1b7b3d2e6b14b913f0b9306e41dada02': {'src_id': '1999.01', 'tgt_id': '工业工程', 'content': '出版时间, 时间节点1999.01工业工程《工业工程》期刊在1999年1月发表了相关论文，指出了期刊的出版时间。'}, 'rel-64c1f058089fd8d7cf7e5c3f87fd6bab': {'src_id': '工业工程', 'tgt_id': '期刊论文', 'content': '学术交流, 出版类型工业工程期刊论文《工业工程 ...
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# DEBUG:lightrag:[upserting chunks] {'chunk-c3ddc19663e979c22961236d629d7faa': {'tokens': 60, 'content': 'title: 基于WWW的交互式网络课件系统的开发技术\nauthors: 傅秀芬，汤庸\nsource: 计算机工程与应用\nsourceDetail: \ndate: 1998.-\ntype: 期刊论文\nkeyword: \nsummary:', 'chunk_order_index': 0, 'full_doc_id': 'doc-c3ddc19663e979c22961236d629d7faa'}, 'chunk-49dcb89e79b16caced258e08371122e5': {'tokens': 71, 'content': 'title: 时态变量“Now”语义及相应时态关系运算\nauthors: 叶小平，汤庸\nsource: 软件学报，2005，16（5）：838-845\nsourceDetail: \ndate: 2005.05\ntype: 期刊论文\nkeyword: \nsummary:', 'chunk_order_index': 0, 'full_doc_id': 'doc-49dcb89e79b16caced258e08371122e5'}, 'chunk-52c7b60eb2f46bca990151794d9339c5': {'tokens': 61, 'content': 'title: 计算机支持的协同工作概观\nauthors: 汤庸\nsource: 工业工程,1999,2(003):10-12\nsourceDetail: \ndate: 1999.01\ntype: 期刊论文\nkeyword: \nsummary:', 'chunk_order_index': 0, 'full_doc_id': 'doc-52c7b60eb2f46bca990151794d9339c5'}, 'chunk-73f68d1cc6f8d7d1f23ed5eea890ca32': {'tokens': 79, 'content': 'title: 时态知识和时态数据的统一模型研究\nauthors: 汤庸，汤娜，叶小平，冯智圣，肖炜\nsource: 软件学报，2003，14(S),74-79 【EI】\nsourceDetail: \ndate: 2003.11\ntype: 期刊论文\nkeyword: \nsummary:', 'chunk_order_index': 0, 'full_doc_id': 'doc-73f68d1cc6f8d7d1f23ed5eea890ca32'}, 'chunk-7061677a44e71bde3b7d8f5c3bebb5ee': {'tokens': 72, 'content': 'title: 基于描述逻辑的CIM模型\nauthors: 蒋运承 汤庸 王驹 周生明\nsource: 微电子学与计算机,2007,24(012):55-58\nsourceDetail: \ndate: 2007.-\ntype: 期刊论文\nkeyword: \nsummary:', 'chunk_order_index': 0, 'full_doc_id': 'doc-7061677a44e71bde3b7d8f5c3bebb5ee'}, 'chunk-7ee1d44c4e5eac0bbcba30cea0223dd9': {'tokens': 59, 'content': 'title: CD—ROM信息存储与检索技术\nauthors: 汤庸\nsource: 计算机时代     1996年 第01期\nsourceDetail: \ndate: 1996.01\ntype: 期刊论文\nkeyword: \nsummary:', 'chunk_order_index': 0, 'full_doc_id': 'doc-7ee1d44c4e5eac0bbcba30cea0223dd9'}}
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://192.168.69.234:11343/api/embed "HTTP/1.1 200 OK"
# KG successfully indexed.

# %%
# Read the content of the file
with open("../data/temp.txt", "r", encoding="utf-8") as file:
    file_content = file.read()

llm_model_func.start_time = time.time()
# await rag.ainsert(file_content)
# print(f"函数调用次数: {llm_model_func.call_count}，总时间: {llm_model_func.end_time - llm_model_func.start_time}s，速率: {llm_model_func.rate} 次/分钟")

tasks = []
tasks.append(rag.ainsert(file_content))

async def print_rate():
    await asyncio.sleep(60)
    for i in range(18):
        await asyncio.sleep(10)
        print(f"函数调用次数: {llm_model_func.call_count}，总时间: {llm_model_func.end_time - llm_model_func.start_time}s，速率: {llm_model_func.rate} 次/分钟")

tasks.append(print_rate())

await asyncio.gather(*tasks)
print(f"函数调用次数: {llm_model_func.call_count}，总时间: {llm_model_func.end_time - llm_model_func.start_time}s，速率: {llm_model_func.rate} 次/分钟")

# %% [markdown]
# ## 问答

# %%
# await rag.adelete_by_entity("汤庸")

# %%
res = await rag.aquery(
        "汤庸有哪些成就？",
        param=QueryParam(mode="local", only_need_context=True),
    )

print(len(res))
print(res)

# %% [markdown]
# ### 可视化本地图为网页

# %%
import networkx as nx
from pyvis.network import Network
import random

# Load the GraphML file
G = nx.read_graphml("../data/test_paper/graph_chunk_entity_relation.graphml")

# Create a Pyvis network
net = Network(height="100vh", notebook=True)

# Convert NetworkX graph to Pyvis network
net.from_nx(G)

# Add colors to nodes
for node in net.nodes:
    node["color"] = "#{:06x}".format(random.randint(0, 0xFFFFFF))

# Save and display the network
net.show("../data/test_paper/knowledge_graph.html")

# %% [markdown]
# ### 可视化本地图到 neo4j

# %%
import os
import json
from lightrag.utils import xml_to_json
from neo4j import GraphDatabase

# Constants
BATCH_SIZE_NODES = 500
BATCH_SIZE_EDGES = 100

# Neo4j connection credentials
NEO4J_URI = "bolt://localhost:7687"
NEO4J_USERNAME = "neo4j"
NEO4J_PASSWORD = "12345678"


def convert_xml_to_json(xml_path, output_path):
    """Converts XML file to JSON and saves the output."""
    if not os.path.exists(xml_path):
        print(f"Error: File not found - {xml_path}")
        return None

    json_data = xml_to_json(xml_path)
    if json_data:
        with open(output_path, "w", encoding="utf-8") as f:
            json.dump(json_data, f, ensure_ascii=False, indent=2)
        print(f"JSON file created: {output_path}")
        return json_data
    else:
        print("Failed to create JSON data")
        return None


def process_in_batches(tx, query, data, batch_size):
    """Process data in batches and execute the given query."""
    for i in range(0, len(data), batch_size):
        batch = data[i : i + batch_size]
        tx.run(query, {"nodes": batch} if "nodes" in query else {"edges": batch})


def main():
    # Paths
    xml_file = os.path.join(WORKING_DIR, "graph_chunk_entity_relation.graphml")
    json_file = os.path.join(WORKING_DIR, "graph_data.json")

    # Convert XML to JSON
    json_data = convert_xml_to_json(xml_file, json_file)
    if json_data is None:
        return

    # Load nodes and edges
    nodes = json_data.get("nodes", [])
    edges = json_data.get("edges", [])

    # Neo4j queries
    create_nodes_query = """
    UNWIND $nodes AS node
    MERGE (e:Entity {id: node.id})
    SET e.entity_type = node.entity_type,
        e.description = node.description,
        e.source_id = node.source_id,
        e.displayName = node.id
    REMOVE e:Entity
    WITH e, node
    CALL apoc.create.addLabels(e, [node.entity_type]) YIELD node AS labeledNode
    RETURN count(*)
    """

    create_edges_query = """
    UNWIND $edges AS edge
    MATCH (source {id: edge.source})
    MATCH (target {id: edge.target})
    WITH source, target, edge,
         CASE
            WHEN edge.keywords CONTAINS 'lead' THEN 'lead'
            WHEN edge.keywords CONTAINS 'participate' THEN 'participate'
            WHEN edge.keywords CONTAINS 'uses' THEN 'uses'
            WHEN edge.keywords CONTAINS 'located' THEN 'located'
            WHEN edge.keywords CONTAINS 'occurs' THEN 'occurs'
           ELSE REPLACE(SPLIT(edge.keywords, ',')[0], '\"', '')
         END AS relType
    CALL apoc.create.relationship(source, relType, {
      weight: edge.weight,
      description: edge.description,
      keywords: edge.keywords,
      source_id: edge.source_id
    }, target) YIELD rel
    RETURN count(*)
    """

    set_displayname_and_labels_query = """
    MATCH (n)
    SET n.displayName = n.id
    WITH n
    CALL apoc.create.setLabels(n, [n.entity_type]) YIELD node
    RETURN count(*)
    """

    # Create a Neo4j driver
    driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

    try:
        # Execute queries in batches
        with driver.session() as session:
            # Insert nodes in batches
            session.execute_write(
                process_in_batches, create_nodes_query, nodes, BATCH_SIZE_NODES
            )

            # Insert edges in batches
            session.execute_write(
                process_in_batches, create_edges_query, edges, BATCH_SIZE_EDGES
            )

            # Set displayName and labels
            session.run(set_displayname_and_labels_query)

    except Exception as e:
        print(f"Error occurred: {e}")

    finally:
        driver.close()


main()
